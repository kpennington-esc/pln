# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import f1_score

# %%
newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
newsgroups_test = fetch_20newsgroups(subset='test', remove=('headers', 'footers', 'quotes'))

# %%
# vectorizacion y split
tfidfvect = TfidfVectorizer()
X_train = tfidfvect.fit_transform(newsgroups_train.data)
y_train = newsgroups_train.target

# %% [markdown]
# ## 1. Vectorizar documentos.

# %%
# pick 5 
np.random.seed(42)  
random_idxs = np.random.choice(X_train.shape[0], size=5, replace=False)

# %%
for idx in random_idxs:
    print("="*80)
    print(f"DOCUMENTO {idx:10} \t(CLASE: {newsgroups_train.target_names[y_train[idx]]})")
    print("-"*80)

    # similaridad con el resto de los documentos
    cossim = cosine_similarity(X_train[idx], X_train)[0]
    mostsim = np.argsort(cossim)[::-1][1:6]  # skip itself [0]

    for i in mostsim:
        print(f"  -> SIMILAR {i:10} | CLASE: {newsgroups_train.target_names[y_train[i]]:30} | sim={cossim[i]:.3f}")
# Out:
# ================================================================================
# DOCUMENTO       7492 	(CLASE: comp.sys.mac.hardware)
# --------------------------------------------------------------------------------
#   -> SIMILAR      10935 | CLASE: comp.sys.mac.hardware          | sim=0.667
#   -> SIMILAR       7258 | CLASE: comp.sys.ibm.pc.hardware       | sim=0.348
#   -> SIMILAR       4971 | CLASE: comp.sys.mac.hardware          | sim=0.180
#   -> SIMILAR       4303 | CLASE: misc.forsale                   | sim=0.155
#   -> SIMILAR        645 | CLASE: comp.sys.mac.hardware          | sim=0.141
# ================================================================================
# DOCUMENTO       3546 	(CLASE: comp.os.ms-windows.misc)
# --------------------------------------------------------------------------------
#   -> SIMILAR       5665 | CLASE: comp.sys.ibm.pc.hardware       | sim=0.204
#   -> SIMILAR       2011 | CLASE: comp.sys.ibm.pc.hardware       | sim=0.192
#   -> SIMILAR       8643 | CLASE: comp.sys.ibm.pc.hardware       | sim=0.172
#   -> SIMILAR       1546 | CLASE: comp.sys.ibm.pc.hardware       | sim=0.171
#   -> SIMILAR       8765 | CLASE: comp.sys.ibm.pc.hardware       | sim=0.162
# ================================================================================
# DOCUMENTO       5582 	(CLASE: misc.forsale)
# --------------------------------------------------------------------------------
#   -> SIMILAR       5510 | CLASE: misc.forsale                   | sim=0.462
#   -> SIMILAR       4922 | CLASE: misc.forsale                   | sim=0.300
#   -> SIMILAR       4347 | CLASE: comp.graphics                  | sim=0.274
#   -> SIMILAR       8057 | CLASE: misc.forsale                   | sim=0.208
#   -> SIMILAR       4028 | CLASE: comp.graphics                  | sim=0.169
# ================================================================================
# DOCUMENTO       4793 	(CLASE: talk.politics.guns)
# --------------------------------------------------------------------------------
#   -> SIMILAR       6894 | CLASE: talk.politics.guns             | sim=0.236
#   -> SIMILAR       5856 | CLASE: sci.crypt                      | sim=0.236
#   -> SIMILAR       4271 | CLASE: talk.politics.misc             | sim=0.233
#   -> SIMILAR       3141 | CLASE: talk.politics.guns             | sim=0.230
#   -> SIMILAR      10836 | CLASE: alt.atheism                    | sim=0.229
# ================================================================================
# DOCUMENTO       3813 	(CLASE: rec.sport.hockey)
# --------------------------------------------------------------------------------
#   -> SIMILAR      10836 | CLASE: alt.atheism                    | sim=0.251
#   -> SIMILAR        759 | CLASE: soc.religion.christian         | sim=0.248
#   -> SIMILAR        913 | CLASE: alt.atheism                    | sim=0.241
#   -> SIMILAR       5826 | CLASE: soc.religion.christian         | sim=0.241
#   -> SIMILAR       5856 | CLASE: sci.crypt                      | sim=0.233

# %%
# algunos ejemplos
example_idx = random_idxs[0]
print("="*80)
print(f"DOCUMENTO ORIGINAL {example_idx} (CLASE: {newsgroups_train.target_names[y_train[example_idx]]})")
print(newsgroups_train.data[example_idx][:500], "...\n")  

cossim = cosine_similarity(X_train[example_idx], X_train)[0]
mostsim = np.argsort(cossim)[::-1][1:6]

for i in mostsim[:2]:  
    print(f"DOCUMENTO SIMILAR {i} (CLASE: {newsgroups_train.target_names[y_train[i]]}, sim={cossim[i]:.3f})")
    print(newsgroups_train.data[i][:500], "...\n")
print("="*80)
# Out:
# ================================================================================
# DOCUMENTO ORIGINAL 7492 (CLASE: comp.sys.mac.hardware)
# Could someone please post any info on these systems.
#
# Thanks.
# BoB
# --
# ----------------------------------------------------------------------
# Robert Novitskey | "Pursuing women is similar to banging one's head
# rrn@po.cwru.edu  |  against a wall...with less opportunity for reward"  ...
#
# DOCUMENTO SIMILAR 10935 (CLASE: comp.sys.mac.hardware, sim=0.667)
# Hey everybody:
#
#    I want to buy a mac and I want to get a good price...who doesn't?  So,
# could anyone out there who has found a really good deal on a Centris 650
# send me the price.  I don't want to know where, unless it is mail order or
# areound cleveland, Ohio.  Also, should I buy now or wait for the Power PC.
#
# Thanks.
# BoB
# reply via post or e-mail at rrn@po.cwru.edu
# --
# ----------------------------------------------------------------------
# Robert Novitskey | "Pursuing women is similar to bangi ...
#
# DOCUMENTO SIMILAR 7258 (CLASE: comp.sys.ibm.pc.hardware, sim=0.348)
# Hay all:
#
#     Has anyone out there heard of any performance stats on the fabled p24t.
#  I was wondering what it's performance compared to the 486/66 and/or
# pentium would be.  Any info would be helpful.
#
# Later
# BoB
# --
# Robert Novitskey | rrn@po.cwru.edu | (216)754-2134 | CWRU Cleve. Ohio
# ----------------------------------------------------------------------
# COMPUTER ENGINEER AND C PROGRAMMER |  NOW SEEKING SUMMER JOBS ...
#
# ================================================================================

# %% [markdown]
# ## 2. Construir un modelo de clasificación por prototipos

# %%
X_test  = tfidfvect.transform(newsgroups_test.data)
y_test  = newsgroups_test.target
sim_matrix = cosine_similarity(X_test, X_train)

# %%
nearest_train_idx = np.argmax(sim_matrix, axis=1)
y_pred_pre = y_train[nearest_train_idx]

# %%
f1_macro = f1_score(y_test, y_pred_pre, average="macro")
print(f"Macro F1: {f1_macro:.4f}")
# Out:
# Macro F1: 0.5050

# %% [markdown]
# ## 3. Entrenar modelos de clasificación Naïve Bayes

# %%
# multinomial
tfidfvect = TfidfVectorizer()
X_train = tfidfvect.fit_transform(newsgroups_train.data)
X_test  = tfidfvect.transform(newsgroups_test.data)
mnb = MultinomialNB()
mnb.fit(X_train, y_train)
y_pred_mnb = mnb.predict(X_test)
# complement
cnb = ComplementNB()
cnb.fit(X_train, y_train)
y_pred_cnb = cnb.predict(X_test)

# %%
print(f"MNB  Macro F1: {f1_score(y_test, y_pred_mnb, average='macro'):.3f}")
print(f"CNB  Macro F1: {f1_score(y_test, y_pred_cnb, average='macro'):.3f}")
# Out:
# MNB  Macro F1: 0.585
# CNB  Macro F1: 0.693

# %% [markdown]
# Sin ningun tipo de _tuneo_ los calsificadores de naive bayes obtienne f1 scores mas altos que la clasificacion por prototipos

# %%
tfidfvect = TfidfVectorizer(stop_words="english")
X_train = tfidfvect.fit_transform(newsgroups_train.data)
X_test  = tfidfvect.transform(newsgroups_test.data)
mnb = MultinomialNB()
mnb.fit(X_train, y_train)
y_pred_mnb = mnb.predict(X_test)
cnb = ComplementNB()
cnb.fit(X_train, y_train)
y_pred_cnb = cnb.predict(X_test)
print(f"MNB  Macro F1: {f1_score(y_test, y_pred_mnb, average='macro'):.3f}")
print(f"CNB  Macro F1: {f1_score(y_test, y_pred_cnb, average='macro'):.3f}")
# Out:
# MNB  Macro F1: 0.647
# CNB  Macro F1: 0.694

# %% [markdown]
# vemos que agregando stop_words el score para MNB sube considerablemente:
#
#     stop_words{‘english’}, list, default=None
#
#     If a string, it is passed to _check_stop_list and the appropriate stop list is returned. ‘english’ is currently the only supported string value. There are several known issues with ‘english’ and you should consider an alternative (see Using stop words).
#
#     If a list, that list is assumed to contain stop words, all of which will be removed from the resulting tokens. Only applies if analyzer == 'word'.
#
#     If None, no stop words will be used. In this case, setting max_df to a higher value, such as in the range (0.7, 1.0), can automatically detect and filter stop words based on intra corpus document frequency of terms.
#
# le hacemos caso y probamos con None y max_df:

# %%
max_dfs = [0.1, 0.2, 0.5, 0.7, 1.0]
for max_df in max_dfs:
    tfidfvect = TfidfVectorizer(max_df=max_df)
    X_train = tfidfvect.fit_transform(newsgroups_train.data)
    X_test  = tfidfvect.transform(newsgroups_test.data)
    mnb = MultinomialNB()
    mnb.fit(X_train, y_train)
    y_pred_mnb = mnb.predict(X_test)
    cnb = ComplementNB()
    cnb.fit(X_train, y_train)
    y_pred_cnb = cnb.predict(X_test)
    print(f"MAX DF: {max_df}")
    print(f"\tMNB  Macro F1: {f1_score(y_test, y_pred_mnb, average='macro'):.3f}")
    print(f"\tCNB  Macro F1: {f1_score(y_test, y_pred_cnb, average='macro'):.3f}")
# Out:
# MAX DF: 0.1
# 	MNB  Macro F1: 0.643
# 	CNB  Macro F1: 0.695
# MAX DF: 0.2
# 	MNB  Macro F1: 0.627
# 	CNB  Macro F1: 0.694
# MAX DF: 0.5
# 	MNB  Macro F1: 0.601
# 	CNB  Macro F1: 0.693
# MAX DF: 0.7
# 	MNB  Macro F1: 0.591
# 	CNB  Macro F1: 0.692
# MAX DF: 1.0
# 	MNB  Macro F1: 0.585
# 	CNB  Macro F1: 0.693

# %% [markdown]
# Un valor bajo de `max_df` mejora el score, con 0.1 el f1 para mnb es similar a usar `stop_words='english'`
#
# Ademas podemos usar `ngram_range` para que el algoritmo considere n-gramas

# %%
tfidfvect = TfidfVectorizer(stop_words="english", max_df=0.1, ngram_range=(1,2))
X_train = tfidfvect.fit_transform(newsgroups_train.data)
X_test  = tfidfvect.transform(newsgroups_test.data)
mnb = MultinomialNB()
mnb.fit(X_train, y_train)
y_pred_mnb = mnb.predict(X_test)
cnb = ComplementNB()
cnb.fit(X_train, y_train)
y_pred_cnb = cnb.predict(X_test)
print(f"MNB  Macro F1: {f1_score(y_test, y_pred_mnb, average='macro'):.2f}")
print(f"CNB  Macro F1: {f1_score(y_test, y_pred_cnb, average='macro'):.2f}")
# Out:
# MNB  Macro F1: 0.65
# CNB  Macro F1: 0.70

# %% [markdown]
# ## 4. Transponer la matriz documento-término.

# %%
tfidfvect = TfidfVectorizer(stop_words="english", max_df=0.1) # saco los 2-gramas

X_train = tfidfvect.fit_transform(newsgroups_train.data)
X_dag = X_train.T

# %%
idx2word = {v: k for k, v in tfidfvect.vocabulary_.items()}
idx2word
# Out:
# {96859: 'wondering',
#  37254: 'enlighten',
#  25717: 'car',
#  80409: 'saw',
#  31927: 'day',
#  34739: 'door',
#  84300: 'sports',
#  57241: 'looked',
#  55601: 'late',
#  9843: '60s',
#  35900: 'early',
#  11174: '70s',
#  25437: 'called',
#  24108: 'bricklin',
#  34740: 'doors',
#  76259: 'really',
#  83196: 'small',
#  16806: 'addition',
#  24583: 'bumper',
#  81438: 'separate',
#  77666: 'rest',
#  23430: 'body',
#  87901: 'tellme',
#  62587: 'model',
#  37206: 'engine',
#  84038: 'specs',
#  99588: 'years',
#  73164: 'production',
#  46687: 'history',
#  49797: 'info',
#  41872: 'funky',
#  57244: 'looking',
#  59065: 'mail',
#  39294: 'fair',
#  66671: 'number',
#  23973: 'brave',
#  83767: 'souls',
#  92374: 'upgraded',
#  82325: 'si',
#  27889: 'clock',
#  68510: 'oscillator',
#  81836: 'shared',
#  38635: 'experiences',
#  72029: 'poll',
#  81366: 'send',
#  24125: 'brief',
#  60916: 'message',
#  33127: 'detailing',
#  73112: 'procedure',
#  84076: 'speed',
#  20236: 'attained',
#  30233: 'cpu',
#  75894: 'rated',
#  16791: 'add',
#  25769: 'cards',
#  16776: 'adapters',
#  45994: 'heat',
#  82654: 'sinks',
#  47307: 'hour',
#  92573: 'usage',
#  40725: 'floppy',
#  34011: 'disk',
#  41834: 'functionality',
#  12266: '800',
#  40723: 'floppies',
#  37865: 'especially',
#  77450: 'requested',
#  86064: 'summarizing',
#  31942: 'days',
#  65369: 'network',
#  54499: 'knowledge',
#  21688: 'base',
#  92371: 'upgrade',
#  45772: 'haven',
#  18757: 'answered',
#  40948: 'folks',
#  58771: 'mac',
#  71768: 'plus',
#  40282: 'finally',
#  42678: 'gave',
#  43237: 'ghost',
#  95845: 'weekend',
#  84909: 'starting',
#  56525: 'life',
#  8677: '512k',
#  3483: '1985',
#  83702: 'sooo',
#  59545: 'market',
#  58812: 'machine',
#  22913: 'bit',
#  83701: 'sooner',
#  50299: 'intended',
#  71129: 'picking',
#  72389: 'powerbook',
#  2940: '160',
#  59928: 'maybe',
#  3248: '180',
#  24591: 'bunch',
#  75085: 'questions',
#  47148: 'hopefully',
#  83648: 'somebody',
#  18755: 'answer',
#  18883: 'anybody',
#  33760: 'dirt',
#  79026: 'round',
#  50594: 'introductions',
#  38602: 'expected',
#  45972: 'heard',
#  3301: '185c',
#  86296: 'supposed',
#  19072: 'appearence',
#  86067: 'summer',
#  18889: 'anymore',
#  16417: 'access',
#  58858: 'macleak',
#  79362: 'rumors',
#  72942: 'price',
#  35111: 'drops',
#  56670: 'line',
#  67920: 'ones',
#  35383: 'duo',
#  95946: 'went',
#  76387: 'recently',
#  49248: 'impression',
#  34113: 'display',
#  73081: 'probably',
#  86636: 'swing',
#  43911: 'got',
#  12356: '80mb',
#  2223: '120',
#  39785: 'feel',
#  22475: 'better',
#  99582: 'yea',
#  57248: 'looks',
#  44238: 'great',
#  85337: 'store',
#  97031: 'wow',
#  83598: 'solicit',
#  68079: 'opinions',
#  96999: 'worth',
#  87371: 'taking',
#  82747: 'size',
#  62787: 'money',
#  46689: 'hit',
#  16690: 'active',
#  76251: 'realize',
#  76231: 'real',
#  85728: 'subjective',
#  75073: 'question',
#  71610: 'played',
#  58820: 'machines',
#  28881: 'computer',
#  24044: 'breifly',
#  40176: 'figured',
#  16715: 'actually',
#  92607: 'uses',
#  31623: 'daily',
#  73541: 'prove',
#  46160: 'helpful',
#  46131: 'hellcats',
#  70484: 'perform',
#  17003: 'advance',
#  36807: 'email',
#  56982: 'll',
#  72281: 'post',
#  86065: 'summary',
#  65508: 'news',
#  76208: 'reading',
#  72751: 'premium',
#  40283: 'finals',
#  29852: 'corner',
#  89169: 'tom',
#  96383: 'willis',
#  90475: 'twillis',
#  36080: 'ecn',
#  73964: 'purdue',
#  36232: 'edu',
#  36610: 'electrical',
#  37210: 'engineering',
#  95901: 'weitek',
#  16818: 'address',
#  70975: 'phone',
#  49819: 'information',
#  26997: 'chip',
#  19689: 'article',
#  25113: 'c5owcb',
#  64536: 'n3p',
#  96963: 'world',
#  84996: 'std',
#  28405: 'com',
#  89180: 'tombaker',
#  21413: 'baker',
#  91625: 'understanding',
#  37737: 'errors',
#  21725: 'basically',
#  54504: 'known',
#  24497: 'bugs',
#  95516: 'warning',
#  83545: 'software',
#  88471: 'things',
#  26809: 'checked',
#  93308: 'values',
#  19421: 'aren',
#  81575: 'set',
#  88805: 'till',
#  55648: 'launch',
#  85923: 'suchlike',
#  40438: 'fix',
#  28151: 'code',
#  72280: 'possibly',
#  50589: 'introduce',
#  87896: 'tell',
#  30414: 'crew',
#  67672: 'ok',
#  4520: '213',
#  56545: 'liftoff',
#  48694: 'ignore',
#  30091: 'course',
#  88030: 'term',
#  78211: 'rigidly',
#  32452: 'defined',
#  34807: 'doubt',
#  92620: 'using',
#  75167: 'quote',
#  17943: 'allegedly',
#  76197: 'read',
#  72813: 'presenting',
#  19462: 'argument',
#  95791: 'weapons',
#  59695: 'mass',
#  33112: 'destruction',
#  28575: 'commonly',
#  91635: 'understood',
#  86654: 'switching',
#  89266: 'topics',
#  71940: 'point',
#  38230: 'evidently',
#  18006: 'allowed',
#  55607: 'later',
#  18442: 'analysis',
#  43385: 'given',
#  29305: 'consider',
#  27692: 'class',
#  77638: 'responded',
#  77449: 'request',
#  89852: 'treatment',
#  20036: 'astrocytomas',
#  30015: 'couldn',
#  88260: 'thank',
#  33745: 'directly',
#  23749: 'bouncing',
#  73101: 'probs',
#  81066: 'sean',
#  32138: 'debra',
#  81848: 'sharon',
#  88553: 'thought',
#  73801: 'publicly',
#  86338: 'sure',
#  43474: 'glad',
#  16434: 'accidentally',
#  78605: 'rn',
#  50185: 'instead',
#  78540: 'rm',
#  90143: 'trying',
#  32588: 'delete',
#  40215: 'file',
#  81466: 'september',
#  46820: 'hmmm',
#  82210: 'shows',
#  80933: 'scsi',
#  29587: 'controler',
#  75806: 'range',
#  9463: '5mb',
#  29593: 'controller',
#  10776: '6mb',
#  1883: '10mb',
#  24698: 'burst',
#  66340: 'note',
#  49475: 'increase',
#  74948: 'quadra',
#  93821: 'version',
#  38532: 'exist',
#  70131: 'pc',
#  62582: 'mode',
#  2939: '16',
#  96283: 'wide',
#  39506: 'fast',
#  2402: '12mb',
#  4463: '20mb',
#  6203: '32',
#  2777: '15',
#  7521: '40mb',
#  31820: 'data',
#  90466: 'twice',
#  37827: 'esdi',
#  29884: 'correct',
#  76175: 'reach',
#  4306: '20',
#  39513: 'faster',
#  48518: 'ide',
#  13781: '96',
#  39241: 'facts',
#  72293: 'posted',
#  65521: 'newsgroup',
#  48355: 'ibm',
#  81922: 'sheet',
#  20583: 'available',
#  41726: 'ftp',
#  86050: 'sumex',
#  17514: 'aim',
#  84847: 'stanford',
#  6576: '36',
#  7699: '44',
#  77357: 'report',
#  28642: 'compare',
#  90531: 'txt',
#  3156: '173',
#  2956: '161',
#  73093: 'problem',
#  49444: 'inconsiant',
#  34589: 'documented',
#  19094: 'apple',
#  80094: 'salesperson',
#  80044: 'said',
#  59914: 'maximum',
#  86791: 'synchronous',
#  18760: 'ansynchronous',
#  83125: 'slower',
#  50375: 'interface',
#  35081: 'driven',
#  90085: 'true',
#  96408: 'win',
#  34854: 'downloaded',
#  48448: 'icons',
#  23319: 'bmp',
#  40175: 'figure',
#  26651: 'change',
#  95424: 'wallpaper',
#  46155: 'help',
#  19162: 'appreciated',
#  88271: 'thanx',
#  23947: 'brando',
#  23375: 'board',
#  99585: 'year',
#  96928: 'work',
#  34014: 'diskdoubler',
#  20502: 'autodoubler',
#  56489: 'licensing',
#  84748: 'stac',
#  87771: 'technologies',
#  69015: 'owners',
#  28828: 'compression',
#  87772: 'technology',
#  97146: 'writing',
#  60753: 'memory',
#  57325: 'lost',
#  76690: 'reference',
#  97158: 'wrong',
#  73098: 'problems',
#  45554: 'hard',
#  39558: 'fault',
#  32266: 'decompress',
#  90060: 'troubled',
#  76478: 'recompress',
#  48438: 'icon',
#  92666: 'usually',
#  76285: 'reappears',
#  60805: 'mentioned',
#  41491: 'freeware',
#  38590: 'expansion',
#  92719: 'utility',
#  32033: 'dd',
#  38580: 'expand',
#  28823: 'compressed',
#  91965: 'unless',
#  50169: 'installed',
#  73162: 'product',
#  91970: 'unlikely',
#  46961: 'holes',
#  76983: 'related',
#  40443: 'fixed',
#  79971: 'sad',
#  59156: 'makes',
#  77098: 'reluctant',
#  24796: 'buy',
#  85226: 'stinky',
#  46356: 'hey',
#  28723: 'competition',
#  35280: 'ducati',
#  13404: '900gts',
#  3473: '1978',
#  3230: '17k',
#  79387: 'runs',
#  69440: 'paint',
#  24239: 'bronze',
#  24271: 'brown',
#  68226: 'orange',
#  39252: 'faded',
#  55870: 'leaks',
#  67636: 'oil',
#  72157: 'pops',
#  4107: '1st',
#  16382: 'accel',
#  82115: 'shop',
#  89624: 'trans',
#  55865: 'leak',
#  83579: 'sold',
#  22729: 'bike',
#  69014: 'owner',
#  6425: '3495',
#  88479: 'thinking',
#  7148: '3k',
#  65702: 'nice',
#  84745: 'stable',
#  59755: 'mate',
#  22088: 'beemer',
#  51771: 'jap',
#  20810: 'axis',
#  63113: 'motors',
#  90244: 'tuba',
#  50995: 'irwin',
#  47102: 'honk',
#  28894: 'computrac',
#  78110: 'richardson',
#  90510: 'tx',
#  28018: 'cmptrc',
#  57211: 'lonestar',
#  68316: 'org',
#  34594: 'dod',
#  784: '0826',
#  75476: 'r75',
#  99626: 'yep',
#  72897: 'pretty',
#  52033: 'jew',
#  91621: 'understand',
#  52038: 'jewish',
#  52042: 'jews',
#  22223: 'believe',
#  30119: 'covenant',
#  99709: 'yhwh',
#  69997: 'patriarchs',
#  16258: 'abraham',
#  63032: 'moses',
#  25910: 'case',
#  37908: 'establishes',
#  62933: 'moral',
#  40952: 'follow',
#  59355: 'mankind',
#  32200: 'decide',
#  23751: 'boundaries',
#  39339: 'fall',
#  79983: 'sadducees',
#  22224: 'believed',
#  89292: 'torah',
#  77459: 'required',
#  70871: 'pharisees',
#  18487: 'ancestors',
#  62621: 'modern',
#  52722: 'judaism',
#  50467: 'interpretation',
#  55845: 'lead',
#  62937: 'morality',
#  66638: 'nuances',
#  87414: 'talmud',
#  37890: 'essence',
#  22653: 'biblical',
#  59256: 'man',
#  27148: 'christian',
#  65134: 'necessarily',
#  49561: 'indicate',
#  68751: 'outside',
#  76991: 'relationship',
#  84061: 'speculate',
#  90059: 'trouble',
#  30359: 'created',
#  48956: 'image',
#  60454: 'means',
#  33540: 'different',
#  28443: 'come',
#  28979: 'conclusion',
#  92425: 'upsets',
#  25870: 'cart',
#  95474: 'wants',
#  80895: 'script',
#  81786: 'shaky',
#  41254: 'foundation',
#  62027: 'mix',
#  60975: 'metaphors',
#  91394: 'unashamedly',
#  56879: 'living',
#  27138: 'christ',
#  38369: 'example',
#  56843: 'little',
#  52016: 'jesus',
#  70626: 'person',
#  76510: 'recorded',
#  92760: 'utterances',
#  64828: 'narratives',
#  40955: 'followers',
#  76692: 'references',
#  28905: 'comtemporary',
#  46680: 'historians',
#  77864: 'revelation',
#  19815: 'aside',
#  81120: 'second',
#  45415: 'hand',
#  96986: 'worse',
#  20247: 'attempt',
#  32151: 'debunk',
#  27152: 'christianity',
#  49942: 'initially',
#  22649: 'bible',
#  50466: 'interpret',
#  47645: 'humanity',
#  44636: 'guess',
#  39315: 'faith',
#  77031: 'relevation',
#  28449: 'comes',
#  49903: 'inherent',
#  85730: 'subjectiveness',
#  16289: 'absolute',
#  91679: 'undoubtably',
#  63832: 'multiple',
#  28164: 'codes',
#  41256: 'founded',
#  69714: 'parent',
#  26952: 'child',
#  86572: 'swear',
#  19982: 'assume',
#  86574: 'swears',
#  82571: 'simply',
#  89151: 'told',
#  90048: 'trooper',
#  73786: 'pub',
#  21560: 'bar',
#  26962: 'children',
#  97163: 'wrongness',
#  34057: 'disobeys',
#  49348: 'inappropriate',
#  75144: 'quite',
#  45530: 'happy',
#  18610: 'animals',
#  18434: 'analogy',
#  46947: 'hold',
#  95595: 'water',
#  54505: 'knows',
#  90565: 'type',
#  43374: 'gist',
#  49393: 'incidentally',
#  99887: 'young',
#  29314: 'considers',
#  33743: 'directive',
#  43136: 'gets',
#  67754: 'older',
#  71105: 'piaget',
#  55893: 'learns',
#  31891: 'david',
#  77062: 'religion',
#  32989: 'description',
#  38783: 'external',
#  87462: 'tank',
#  68156: 'option',
#  84639: 'ssf',
#  76590: 'redesign',
#  32589: 'deleted',
#  99849: 'yo',
#  53717: 'ken',
#  56164: 'let',
#  96475: 'wingless',
#  68242: 'orbiter',
#  68160: 'options',
#  56784: 'list',
#  89115: 'today',
#  4670: '23',
#  36197: 'edition',
#  99873: 'york',
#  88839: 'times',
#  77366: 'reports',
#  29238: 'connor',
#  69552: 'panel',
#  73415: 'proposals',
#  35109: 'dropped',
#  43258: 'giant',
#  41776: 'fuel',
#  87469: 'tanks',
#  55653: 'launching',
#  83859: 'space',
#  82281: 'shuttles',
#  24510: 'building',
#  84953: 'station',
#  38543: 'existing',
#  82280: 'shuttle',
#  96479: 'wings',
#  87334: 'tail',
#  77187: 'removed',
#  30989: 'currently',
#  29312: 'considered',
#  72809: 'presented',
#  17057: 'advisory',
#  60598: 'meeting',
#  99642: 'yesterday',
#  77361: 'reported',
#  57381: 'low',
#  29982: 'cost',
#  62653: 'modular',
#  19181: 'approach',
#  85606: 'studied',
#  87726: 'team',
#  63566: 'msfc',
#  87731: 'teams',
#  52653: 'jsc',
#  55536: 'larc',
#  86291: 'supporting',
#  84580: 'srt',
#  30707: 'crystal',
#  27499: 'city',
#  56133: 'lerc',
#  77682: 'reston',
#  82707: 'site',
#  57121: 'locations',
#  46163: 'helping',
#  77629: 'respective',
#  16697: 'activities',
#  53804: 'key',
#  39745: 'features',
#  24710: 'bus',
#  33229: 'developed',
#  57127: 'lockheed',
#  74972: 'qualified',
#  85583: 'sts',
#  36788: 'elv',
#  73559: 'provides',
#  73442: 'propulsion',
#  43664: 'gn',
#  28598: 'communications',
#  59267: 'management',
#  17534: 'air',
#  41040: 'force',
#  72383: 'power',
#  25648: 'capability',
#  67285: 'obtained',
#  40667: 'flights',
#  83571: 'solar',
#  19620: 'arrays',
#  73553: 'provide',
#  54967: 'kw',
#  93636: 'vehicle',
#  40665: 'flies',
#  19652: 'arrow',
#  68149: 'optimize',
#  61423: 'microgravity',
#  37417: 'environment',
#  83872: 'spacelab',
#  61940: 'missions',
#  92721: 'utilize',
#  93639: 'vehilce',
#  83790: 'source',
#  6044: '30',
#  47636: 'human',
#  87957: 'tended',
#  68106: 'opposed',
#  67750: 'old',
#  81654: 'sexist',
#  16570: 'achieved',
#  28571: 'common',
#  62658: 'module',
#  62639: 'modified',
#  55279: 'lab',
#  34562: 'docking',
#  72219: 'ports',
#  16795: 'added',
#  50434: 'international',
#  69849: 'partners',
#  55306: 'labs',
#  71504: 'place',
#  66101: 'nodes',
#  34559: 'docked',
#  9762: '60',
#  45184: 'habitability',
#  38124: 'eva',
#  64847: 'nasda',
#  37781: 'esa',
#  62659: 'modules',
#  70542: 'permanent',
#  72802: 'presence',
#  7312: '3rd',
#  45188: 'habitation',
#  16670: 'acrv',
#  19994: 'assured',
#  77823: 'return',
#  41472: 'freedom',
#  32940: 'derived',
#  21698: 'based',
#  61554: 'mike',
#  44342: 'griffin',
#  18051: 'alot',
#  33018: 'design',
#  57367: 'love',
#  19984: 'assumes',
#  56576: 'lightweight',
#  19916: 'assembly',
#  28880: 'computed',
#  8668: '51',
#  49402: 'inclination',
#  68238: 'orbit',
#  24505: 'build',
#  67345: 'occurs',
#  70884: 'phases',
#  49932: 'initial',
#  77494: 'research',
#  76177: 'reached',
#  89670: 'transferred',
#  94214: 'visits',
#  16951: 'adopted',
#  66145: 'non',
#  55476: 'language',
#  32863: 'deployed',
#  1469: '10',
#  53671: 'keeping',
#  68243: 'orbiters',
#  57185: 'logistics',
#  86283: 'supply',
#  89154: 'tolerance',
#  2593: '14',
#  5688: '2nd',
#  88397: 'thermal',
#  29584: 'control',
#  75621: 'radiator',
#  50439: 'internationals',
#  40322: 'finish',
#  4749: '24',
#  86871: 'systems',
#  38397: 'exception',
#  59135: 'major',
#  26659: 'changes',
#  76626: 'reduced',
#  72946: 'prices',
#  41192: 'forsale',
#  22143: 'behalf',
#  24260: 'brother',
#  63189: 'moving',
#  63176: 'moved',
#  67511: 'offer',
#  23022: 'black',
#  32228: 'decker',
#  35433: 'duster',
#  72198: 'portable',
#  93225: 'vaccum',
#  73958: 'purchased',
#  2222: '12',
#  84519: 'sr',
#  1471: '1000',
#  35257: 'dual',
#  25936: 'cassette',
#  71611: 'player',
#  40808: 'fm',
#  21496: 'band',
#  44149: 'graphics',
#  37584: 'equalizer',
#  46524: 'high',
#  35271: 'dubing',
#  87487: 'tape',
#  32225: 'deck',
#  89858: 'treble',
#  83770: 'sound',
#  22453: 'bet',
#  40439: 'fixable',
#  12265: '80',
#  4899: '25',
#  62832: 'monolux',
#  100957: 'zoom',
#  61450: 'microscope',
#  2230: '1200x',
#  59011: 'magnification',
#  51772: 'japan',
#  49410: 'includes',
#  16428: 'accessories',
#  8581: '50',
#  86096: 'sunbeam',
#  2595: '1400',
#  45265: 'hair',
#  35152: 'dryer',
#  45916: 'head',
#  80120: 'salons',
#  19822: 'ask',
#  24188: 'bro',
#  38209: 'everylast',
#  21361: 'bag',
#  55903: 'leather',
#  23943: 'brand',
#  68563: 'osterizer',
#  74030: 'pusle',
#  59793: 'matic',
#  23128: 'blender',
#  84090: 'speeds',
#  29688: 'cookbook',
#  22820: 'binolux',
#  22819: 'binoculars',
#  12225: '7x35',
#  38801: 'extra',
#  18580: 'angle',
#  8740: '525ft',
#  1536: '1000yds',
#  73144: 'proctor',
#  82487: 'silex',
#  84343: 'spray',
#  85020: 'steam',
#  35149: 'dry',
#  50924: 'iron',
#  29439: 'contact',
#  77348: 'reply',
#  38612: 'expeditously',
#  49407: 'included',
#  55592: 'lastly',
#  76298: 'reasonable',
#  57238: 'look',
#  45520: 'happened',
#  51774: 'japanese',
#  27490: 'citizens',
#  95477: 'war',
#  48743: 'ii',
#  72763: 'prepared',
#  85179: 'stick',
#  28939: 'concentration',
#  25509: 'camp',
#  89904: 'trial',
#  82133: 'short',
#  85085: 'step',
#  42620: 'gassing',
#  64967: 'nazis',
#  68377: 'originally',
#  49256: 'imprison',
#  40277: 'final',
#  83629: 'solution',
#  35027: 'dreamt',
#  69846: 'partly',
#  17210: 'afford',
#  79369: 'run',
#  25528: 'camps',
#  33222: 'devastation',
#  26052: 'caused',
#  43759: 'goering',
#  89358: 'total',
#  95951: 'weren',
#  42616: 'gassed',
#  42921: 'generally',
#  33500: 'died',
#  59225: 'malnutrition',
#  33957: 'disease',
#  26431: 'certainly',
#  88764: 'tiff',
#  96952: 'works',
#  70950: 'philosophically',
#  28771: 'complexity',
#  55936: 'led',
#  73234: 'programs',
#  72132: 'poor',
#  97143: 'writers',
#  59164: 'making',
#  22959: 'bizarre',
#  40235: 'files',
#  49326: 'inability',
#  57071: 'load',
#  48969: 'images',
#  80392: 'save',
#  42911: 'general',
#  50343: 'interchange',
#  37424: 'environments',
#  33074: 'despite',
#  39223: 'fact',
#  80422: 'saying',
#  43761: 'goes',
#  96981: 'worried',
#  16331: 'abuse',
#  26599: 'chalk',
#  49048: 'immense',
#  92014: 'unnecessary',
#  41152: 'format',
#  96918: 'words',
#  83993: 'spec',
#  19086: 'appendix',
#  69405: 'page',
#  25674: 'capitalized',
#  36956: 'emphasis',
#  83747: 'sort',
#  85899: 'success',
#  33024: 'designed',
#  72393: 'powerful',
#  40644: 'flexible',
#  38626: 'expense',
#  82564: 'simplicity',
#  87368: 'takes',
#  36332: 'effort',
#  45451: 'handle',
#  84019: 'specification',
#  19116: 'application',
#  28755: 'complete',
#  52348: 'job',
#  16214: 'able',
#  49214: 'import',
#  42928: 'generating',
#  19119: 'applications',
#  73210: 'program',
#  96849: 'won',
#  32085: 'deal',
#  89785: 'trapped',
#  17378: 'agrees',
#  76304: 'reasoning',
#  19831: 'asking',
#  54121: 'kind',
#  75896: 'rates',
#  82635: 'single',
#  59184: 'male',
#  35084: 'drivers',
#  99963: 'yrs',
#  70072: 'paying',
#  70488: 'performance',
#  25863: 'cars',
#  77345: 'replies',
#  76379: 'received',
#  5071: '27',
#  27905: 'close',
#  3495: '1992',
#  34601: 'dodge',
#  85018: 'stealth',
#  79227: 'rt',
#  90476: 'twin',
#  90318: 'turbo',
#  6061: '300hp',
#  88738: 'tickets',
#  16436: 'accidents',
#  47311: 'house',
#  87363: 'taken',
#  32428: 'defensive',
#  35091: 'driving',
#  17539: 'airbag',
#  16277: 'abs',
#  81167: 'security',
#  17757: 'alarm',
#  2779: '1500',
#  8582: '500',
#  32319: 'decut',
#  84929: 'state',
#  39459: 'farm',
#  50244: 'insurance',
#  16807: 'additional',
#  1470: '100',
#  1: '000',
#  91301: 'umbrella',
#  72001: 'policy',
#  84823: 'standard',
#  6045: '300',
#  23738: 'bought',
#  28634: 'company',
#  16432: 'accident',
#  88736: 'ticket',
#  1912: '11',
#  75168: 'quoted',
#  47145: 'hope',
#  46166: 'helps',
#  85146: 'steve',
#  40806: 'flynn',
#  91930: 'university',
#  32572: 'delaware',
#  7764: '45',
#  53789: 'kevin',
#  77140: 'remembered',
#  29892: 'correctly',
#  19826: 'asked',
#  82534: 'similar',
#  82719: 'situation',
#  50068: 'inquiry',
#  17301: 'age',
#  35881: 'eagle',
#  87415: 'talon',
#  90171: 'tsi',
#  20738: 'awd',
#  76509: 'record',
#  27737: 'clean',
#  48903: 'illinois',
#  12437: '820',
#  63016: 'mos',
#  90366: 'turn',
#  8723: '520',
#  49512: 'incurs',
#  46525: 'higher',
#  75893: 'rate',
#  30071: 'couple',
#  41561: 'friends',
#  20740: 'awds',
#  70065: 'pay',
#  50080: 'ins',
#  28631: 'companies',
#  57628: 'lucky',
#  31685: 'dan',
#  31733: 'dans',
#  51881: 'jdc',
#  44534: 'gss',
#  63058: 'mot',
#  63111: 'motorola',
#  ...}

# %%
words = ['cpu', 'computer', 'religion', 'history', 'space']
for word in words:
  
    word_idx = tfidfvect.vocabulary_[word]
    sims = cosine_similarity(X_dag[word_idx], X_dag)[0]
    mostsim = np.argsort(sims)[::-1][1:6]

    print("="*80)
    print(f"WORD: '{word}'")
    for i in mostsim:
        print(f"  -> {idx2word[i]} (sim={sims[i]:.3f})")
# Out:
# ================================================================================
# WORD: 'cpu'
#   -> dislodge (sim=0.362)
#   -> heatsink (sim=0.316)
#   -> cooler (sim=0.297)
#   -> tasking (sim=0.260)
#   -> bending (sim=0.256)
# ================================================================================
# WORD: 'computer'
#   -> decwriter (sim=0.159)
#   -> harkens (sim=0.152)
#   -> deluged (sim=0.152)
#   -> shopper (sim=0.143)
#   -> delicate (sim=0.136)
# ================================================================================
# WORD: 'religion'
#   -> religious (sim=0.265)
#   -> religions (sim=0.227)
#   -> purpsoe (sim=0.209)
#   -> crusades (sim=0.204)
#   -> categorized (sim=0.199)
# ================================================================================
# WORD: 'history'
#   -> inalcik (sim=0.287)
#   -> hurewitz (sim=0.285)
#   -> chester (sim=0.285)
#   -> nubar (sim=0.285)
#   -> nikolayef (sim=0.285)
# ================================================================================
# WORD: 'space'
#   -> nasa (sim=0.327)
#   -> shuttle (sim=0.289)
#   -> seds (sim=0.283)
#   -> enfant (sim=0.268)
#   -> exploration (sim=0.238)

# %% [markdown]
# Veamos ahora que pasa si consideramos 2-gramas:

# %%
tfidfvect = TfidfVectorizer(stop_words="english", max_df=0.1, ngram_range=(1,2)) # saco los 2-gramas

X_train = tfidfvect.fit_transform(newsgroups_train.data)
X_dag = X_train.T
idx2word = {v: k for k, v in tfidfvect.vocabulary_.items()}
words = ['cpu', 'computer', 'religion', 'history', 'space']
for word in words:
  
    word_idx = tfidfvect.vocabulary_[word]
    sims = cosine_similarity(X_dag[word_idx], X_dag)[0]
    mostsim = np.argsort(sims)[::-1][1:6]

    print("="*80)
    print(f"WORD: '{word}'")
    for i in mostsim:
        print(f"  -> {idx2word[i]} (sim={sims[i]:.3f})")
# Out:
# ================================================================================
# WORD: 'cpu'
#   -> problem ensure (sim=0.426)
#   -> vertical case (sim=0.426)
#   -> weight cooler (sim=0.426)
#   -> weight cpu (sim=0.426)
#   -> cooler chip (sim=0.426)
# ================================================================================
# WORD: 'computer'
#   -> computer science (sim=0.235)
#   -> computer graphics (sim=0.234)
#   -> turn computer (sim=0.206)
#   -> everytime turn (sim=0.178)
#   -> time fix (sim=0.178)
# ================================================================================
# WORD: 'religion'
#   -> say religious (sim=0.316)
#   -> religion does (sim=0.289)
#   -> religious (sim=0.281)
#   -> use religion (sim=0.265)
#   -> freedom religion (sim=0.259)
# ================================================================================
# WORD: 'history'
#   -> turkish studies (sim=0.350)
#   -> inalcik (sim=0.349)
#   -> ottoman history (sim=0.349)
#   -> professor history (sim=0.346)
#   -> michigan list (sim=0.346)
# ================================================================================
# WORD: 'space'
#   -> nasa (sim=0.370)
#   -> space shuttle (sim=0.356)
#   -> seds (sim=0.353)
#   -> space station (sim=0.342)
#   -> shuttle (sim=0.340)

# %% [markdown]
# podemos tunear un poco los parametros del vectorizador...

# %%
tfidfvect = TfidfVectorizer(stop_words="english", max_df=0.3, min_df=5, ngram_range=(1,2)) # saco los 2-gramas

X_train = tfidfvect.fit_transform(newsgroups_train.data)
X_dag = X_train.T
idx2word = {v: k for k, v in tfidfvect.vocabulary_.items()}
words = ['cpu', 'computer', 'religion', 'history', 'space']
for word in words:
  
    word_idx = tfidfvect.vocabulary_[word]
    sims = cosine_similarity(X_dag[word_idx], X_dag)[0]
    mostsim = np.argsort(sims)[::-1][1:6]

    print("="*80)
    print(f"WORD: '{word}'")
    for i in mostsim:
        print(f"  -> {idx2word[i]} (sim={sims[i]:.3f})")
# Out:
# ================================================================================
# WORD: 'cpu'
#   -> cooler (sim=0.289)
#   -> bending (sim=0.246)
#   -> alain (sim=0.240)
#   -> multi tasking (sim=0.238)
#   -> tasking (sim=0.238)
# ================================================================================
# WORD: 'computer'
#   -> computer science (sim=0.232)
#   -> computer graphics (sim=0.223)
#   -> turn computer (sim=0.195)
#   -> use computer (sim=0.174)
#   -> new computer (sim=0.170)
# ================================================================================
# WORD: 'religion'
#   -> religious (sim=0.253)
#   -> religion does (sim=0.250)
#   -> freedom religion (sim=0.230)
#   -> religions (sim=0.228)
#   -> categorized (sim=0.202)
# ================================================================================
# WORD: 'history'
#   -> sic (sim=0.280)
#   -> associate professor (sim=0.264)
#   -> university chicago (sim=0.242)
#   -> stanford shaw (sim=0.229)
#   -> john dewey (sim=0.224)
# ================================================================================
# WORD: 'space'
#   -> space station (sim=0.335)
#   -> nasa (sim=0.321)
#   -> space shuttle (sim=0.308)
#   -> sci space (sim=0.300)
#   -> space exploration (sim=0.293)

# %% [markdown]
# de esta forma aparecen formaciones con "sentido" como
#
# - multi tasking
# - turn/use/new computer
# - associate professor
# - spae station
# - space exploration
